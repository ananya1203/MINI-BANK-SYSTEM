# %%
print("===== MINI BANKING SIMULATION SYSTEM =====")

balance = 0.0
def check_balance():
     print(f"\nYour current balance is: {balance}\n")

def deposit():
    global balance
    amount = float(input("Enter amount to deposit: ₹"))
    if amount > 0:
       balance += amount
       print(f"₹{amount} deposited successfully!")
    else:
        print("Invalid amount!")
    check_balance()
    def withdraw():
      global balance
      amount = float(input("Enter amount to withdraw: ₹"))
      if amount > balance:
         print("Insufficient balance!")
      elif amount <= 0:
          print("Invalid amountt!")
      else:
        balance -= amount
        print(f"₹{amount} withdrawn successfully!")
      check_balance()
      def transfer():
        global balance
        amount = float(input("Enter amount to tranfer: ₹"))

      if amount > balance:
        print("Insufficient balance for transfer!")
      elif amount <= 0:
        print("Invalid amount!")
      else:
        acc = input("Enter receiver amount number: ")
        balance -= amount
        print(f"₹{amount} transferred successfully to A/C  {acc}!")

while True:
          print("""
          ------------------------
                   MENU
          ------------------------
          1. Check balance
          2. Deposit money
          3. Withdraw money
          4. Transfer money
          5. Exit
          ------------------------
          """)
          choice = input("Enter you choice (1-5): ")
          if choice == "1":
            check_balance()
          elif choice == "2":
             deposit()
          elif choice == "3":
             withdraw()
          elif choice == "4":
             tranfer()
          elif choice == "5":
            print("\nThank you for using Mini Banking System!")
            break
          else:
            print("\nInvalid choice! Please choose between 1-5.")
# Out:
# ===== MINI BANKING SIMULATION SYSTEM =====
#
#           ------------------------
#                    MENU
#           ------------------------
#           1. Check balance
#           2. Deposit money
#           3. Withdraw money
#           4. Transfer money
#           5. Exit
#           ------------------------
